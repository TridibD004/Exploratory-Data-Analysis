# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('terrorism.csv',encoding='latin1')
# Out:
# C:\Users\piyas\AppData\Local\Temp\ipykernel_20316\1297027423.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('terrorism.csv',encoding='latin1')

# %%
data
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
# How data looks like

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
# Shape of dataframe

# %%
data.shape
# Out:
# (181691, 135)

# %%
# Is there any ,issing values

# %%
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# Columns

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
for i in data.columns:
    print(i,end="  ")
# Out:
# eventid  iyear  imonth  iday  approxdate  extended  resolution  country  country_txt  region  region_txt  provstate  city  latitude  longitude  specificity  vicinity  location  summary  crit1  crit2  crit3  doubtterr  alternative  alternative_txt  multiple  success  suicide  attacktype1  attacktype1_txt  attacktype2  attacktype2_txt  attacktype3  attacktype3_txt  targtype1  targtype1_txt  targsubtype1  targsubtype1_txt  corp1  target1  natlty1  natlty1_txt  targtype2  targtype2_txt  targsubtype2  targsubtype2_txt  corp2  target2  natlty2  natlty2_txt  targtype3  targtype3_txt  targsubtype3  targsubtype3_txt  corp3  target3  natlty3  natlty3_txt  gname  gsubname  gname2  gsubname2  gname3  gsubname3  motive  guncertain1  guncertain2  guncertain3  individual  nperps  nperpcap  claimed  claimmode  claimmode_txt  claim2  claimmode2  claimmode2_txt  claim3  claimmode3  claimmode3_txt  compclaim  weaptype1  weaptype1_txt  weapsubtype1  weapsubtype1_txt  weaptype2  weaptype2_txt  weapsubtyp
# ...

# %%
# How data look mathematically

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
# Is there any duplicate column

# %%
if(data.duplicated().sum() == 0):
    print("NO DUPLICATE COLUMNS")
else:
    print("There are ",data.duplicated().sum(), "Duplicate columns")
# Out:
# NO DUPLICATE COLUMNS

# %%
# DATA CLEANING

# %%
df = data[["iyear", "imonth", "country_txt", "region_txt", "provstate", "city", "location", "summary",
             "attacktype1_txt", "targtype1_txt", "gname", "motive", "weaptype1_txt", "nkill", "nwound", "property", "addnotes"]]

# %%
df.head()
# Out:
#    iyear  imonth         country_txt                   region_txt provstate  \
# 0   1970       7  Dominican Republic  Central America & Caribbean       NaN
# 1   1970       0              Mexico                North America   Federal
# 2   1970       1         Philippines               Southeast Asia    Tarlac
# 3   1970       1              Greece               Western Europe    Attica
# 4   1970       1               Japan                    East Asia   Fukouka
#
#             city location summary                 attacktype1_txt  \
# 0  Santo Domingo      NaN     NaN                   Assassination
# 1    Mexico city      NaN     NaN     Hostage Taking (Kidnapping)
# 2        Unknown      NaN     NaN                   Assassination
# 3         Athens      NaN     NaN               Bombing/Explosion
# 4        Fukouka      NaN     NaN  Facility/Infrastructure Attack
#
#                  targtype1_txt                               gname motive  \
# ...

# %%
# Changing the columns name

# %%
df.rename(columns= {"iyear":"Year", "imonth":"Month", " iday":"Day", "country_txt":"Country",
                   "region_txt":"Region", "provstate":"Province/State", "city":"City", "location":"Location",
                   "summary":"Summary" ,"attacktype1_txt":"Attack_Type" ,"targtype1_txt":"Target_Type",
                   "gname":"Group_Name", "motive":"Motive","weaptype1_txt":"Weapon_Type",
                   "nkill":"Killed", "nwound":"Wounded", "property": "Property", "addnotes":"Add_Notes"}, inplace = True)
# Out:
# C:\Users\piyas\AppData\Local\Temp\ipykernel_20316\426444347.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns= {"iyear":"Year", "imonth":"Month", " iday":"Day", "country_txt":"Country",

# %%
df.tail()
# Out:
#         Year  Month      Country                      Region   Province/State  \
# 181686  2017     12      Somalia          Sub-Saharan Africa  Middle Shebelle
# 181687  2017     12        Syria  Middle East & North Africa         Lattakia
# 181688  2017     12  Philippines              Southeast Asia      Maguindanao
# 181689  2017     12        India                  South Asia          Manipur
# 181690  2017     12  Philippines              Southeast Asia      Maguindanao
#
#                  City                                           Location  \
# 181686  Ceelka Geelow     The incident occurred near the town of Balcad.
# 181687         Jableh     The incident occurred at the Humaymim Airport.
# 181688       Kubentog  The incident occurred in the Datu Hoffer distr...
# 181689         Imphal  The incident occurred in the Mantripukhri neig...
# 181690  Cotabato City                                                NaN
#
# ...

# %%
# Information of the new dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 17 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   Country         181691 non-null  object
#  3   Region          181691 non-null  object
#  4   Province/State  181270 non-null  object
#  5   City            181257 non-null  object
#  6   Location        55495 non-null   object
#  7   Summary         115562 non-null  object
#  8   Attack_Type     181691 non-null  object
#  9   Target_Type     181691 non-null  object
#  10  Group_Name      181691 non-null  object
#  11  Motive          50561 non-null   object
#  12  Weapon_Type     181691 non-null  object
#  13  Killed          171378 non-null  float64
#  14  Wounded         165380 non-null  float64
#  15  Property        181691 non-null  int64
# ...

# %%
# Is there any null value in the new dataframe

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month                  0
# Country                0
# Region                 0
# Province/State       421
# City                 434
# Location          126196
# Summary            66129
# Attack_Type            0
# Target_Type            0
# Group_Name             0
# Motive            131130
# Weapon_Type            0
# Killed             10313
# Wounded            16311
# Property               0
# Add_Notes         153402
# dtype: int64

# %%
# Dropping motive and location coluums

# %%
df.drop(df.columns[[6, 11]], axis=1, inplace=True)
# Out:
# C:\Users\piyas\AppData\Local\Temp\ipykernel_20316\2910662654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df.columns[[6, 11]], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   Country         181691 non-null  object
#  3   Region          181691 non-null  object
#  4   Province/State  181270 non-null  object
#  5   City            181257 non-null  object
#  6   Summary         115562 non-null  object
#  7   Attack_Type     181691 non-null  object
#  8   Target_Type     181691 non-null  object
#  9   Group_Name      181691 non-null  object
#  10  Weapon_Type     181691 non-null  object
#  11  Killed          171378 non-null  float64
#  12  Wounded         165380 non-null  float64
#  13  Property        181691 non-null  int64
#  14  Add_Notes       28289 non-null   object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 20.8+ MB

# %%
df.shape
# Out:
# (181691, 15)

# %%
df["Killed"]=df["Killed"].fillna(0)
df["Wounded"]=df["Wounded"].fillna(0)
df["Casualty"]=df["Killed"]+df["Wounded"]
# Out:
# C:\Users\piyas\AppData\Local\Temp\ipykernel_20316\2246405792.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Killed"]=df["Killed"].fillna(0)
# C:\Users\piyas\AppData\Local\Temp\ipykernel_20316\2246405792.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Wounded"]=df["Wounded"].fillna(0)
# C:\Users\piyas\AppData\Local\Temp\ipykernel_20316\2246405792.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month                  0
# Country                0
# Region                 0
# Province/State       421
# City                 434
# Summary            66129
# Attack_Type            0
# Target_Type            0
# Group_Name             0
# Weapon_Type            0
# Killed                 0
# Wounded                0
# Property               0
# Add_Notes         153402
# Casualty               0
# dtype: int64

# %%
df.describe()
# Out:
#                 Year          Month         Killed        Wounded  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277       2.266860       2.883296
# std        13.259430       3.388303      11.227057      34.309747
# min      1970.000000       0.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       0.000000       0.000000
# 50%      2009.000000       6.000000       0.000000       0.000000
# 75%      2014.000000       9.000000       2.000000       2.000000
# max      2017.000000      12.000000    1570.000000    8191.000000
#
#             Property       Casualty
# count  181691.000000  181691.000000
# mean       -0.544556       5.150156
# std         3.122889      40.555416
# min        -9.000000       0.000000
# 25%         0.000000       0.000000
# 50%         1.000000       1.000000
# 75%         1.000000       4.000000
# max         1.000000    9574.000000

# %% [markdown]
# ## # OBSERVATION

# %% [markdown]
# #### The dataframe consisit the data of terrorist attact ranging from 1970 to 2017.
# #### Maximum 1570 people were killed in an event.
# #### Maximum 8191 people were wounded in an event.
# #### Maximum number of casualities: 181691

# %%
# Data visualization

# %% [markdown]
# ## Country wise attack

# %% [markdown]
# ### TOP 10 COUNTRIES

# %%
con = df['Country'].value_counts().head(10)
con
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
con.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("Country wise Attacks",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [raw]
# 1) Killed in each country :-

# %%
con_killed = df[["Country","Killed"]].groupby("Country").sum().sort_values(by="Killed", ascending  =False)
con_killed.head(10)
# Out:
#               Killed
# Country
# Iraq         78589.0
# Afghanistan  39384.0
# Pakistan     23822.0
# Nigeria      22682.0
# India        19341.0
# Sri Lanka    15530.0
# Syria        15229.0
# Colombia     14698.0
# Peru         12771.0
# El Salvador  12053.0

# %% [raw]
# 2) Wounded in each country

# %%
con_wound = df[["Country","Wounded"]].groupby("Country").sum().sort_values(by="Wounded", ascending = False)
con_wound.head(10)
# Out:
#                 Wounded
# Country
# Iraq           134690.0
# Afghanistan     44277.0
# Pakistan        42038.0
# India           28980.0
# United States   20702.0
# Sri Lanka       15561.0
# Syria           14109.0
# Philippines     13367.0
# Lebanon         10904.0
# Colombia        10328.0

# %%
# Plotting both killed and wounded

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
con_killed[:10].plot(kind="bar",color="lightgreen",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Country")
ax0.set_xlabel("Countries")
ax0.set_ylabel("Number of People Killed")

#Wounded
con_wound[:10].plot(kind="bar",color="lightgreen",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Country")
ax1.set_xlabel("Countries")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [raw]
# 3) Total casualities (wounded + killeed) in each country

# %%
con_cas = df[['Country', 'Casualty']].groupby("Country").sum().sort_values(by = "Casualty", ascending = False)
con_cas.head(10)
# Out:
#                Casualty
# Country
# Iraq           213279.0
# Afghanistan     83661.0
# Pakistan        65860.0
# India           48321.0
# Nigeria         32921.0
# Sri Lanka       31091.0
# Syria           29338.0
# Colombia        25026.0
# United States   24473.0
# Philippines     22926.0

# %%
con.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("Casulaties in each country",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualty",fontsize=13)
plt.show()

# %% [markdown]
# ## Year Wise Attack

# %%
yr = df['Year'].value_counts().sort_values()
yr
# Out:
# 1971      471
# 1973      473
# 1972      568
# 1974      581
# 1970      651
# 1975      740
# 1976      923
# 1998      934
# 2004     1166
# 2003     1278
# 1977     1319
# 2002     1333
# 1999     1395
# 1978     1526
# 2000     1814
# 2001     1906
# 2005     2017
# 1982     2544
# 1981     2586
# 1980     2662
# 1979     2662
# 2006     2758
# 1986     2860
# 1983     2870
# 1985     2915
# 1996     3058
# 1995     3081
# 1987     3183
# 1997     3197
# 2007     3242
# 1994     3456
# 1984     3495
# 1988     3721
# 1990     3887
# 1989     4324
# 1991     4683
# 2009     4721
# 2008     4805
# 2010     4826
# 1992     5071
# 2011     5076
# 2012     8522
# 2017    10900
# 2013    12036
# 2016    13587
# 2015    14965
# 2014    16903
# Name: Year, dtype: int64

# %%
yr.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("Number of attacks in every year",fontsize=13)
plt.xlabel("Year",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of attacks",fontsize=13)
plt.show()

# %% [raw]
# 1) Year wise total killed

# %%
year_killed = df[["Year", "Killed"]].groupby("Year").sum().sort_values(by = 'Year')
year_killed
# Out:
#        Killed
# Year
# 1970    174.0
# 1971    173.0
# 1972    566.0
# 1973    370.0
# 1974    539.0
# 1975    617.0
# 1976    674.0
# 1977    456.0
# 1978   1459.0
# 1979   2100.0
# 1980   4400.0
# 1981   4851.0
# 1982   5136.0
# 1983   9444.0
# 1984  10450.0
# 1985   7094.0
# 1986   4976.0
# 1987   6482.0
# 1988   7208.0
# 1989   8152.0
# 1990   7148.0
# 1991   8429.0
# 1992   9742.0
# 1994   7690.0
# 1995   6103.0
# 1996   6966.0
# 1997  10924.0
# 1998   4688.0
# 1999   3393.0
# 2000   4403.0
# 2001   7729.0
# 2002   4805.0
# 2003   3317.0
# 2004   5743.0
# 2005   6331.0
# 2006   9380.0
# 2007  12824.0
# 2008   9157.0
# 2009   9273.0
# 2010   7827.0
# 2011   8246.0
# 2012  15497.0
# 2013  22273.0
# 2014  44490.0
# 2015  38853.0
# 2016  34871.0
# 2017  26445.0

# %%
year_killed.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("Total people killed in every year",fontsize=13)
plt.xlabel("Year",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("People Killed",fontsize=13)
plt.show()

# %% [raw]
# 2) Year wise total wounded

# %%
year_wounded = df[["Year", "Wounded"]].groupby("Year").sum().sort_values(by = 'Year')
year_wounded
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0
# 1975    617.0
# 1976    756.0
# 1977    518.0
# 1978   1600.0
# 1979   2506.0
# 1980   3645.0
# 1981   3337.0
# 1982   3342.0
# 1983   4047.0
# 1984   5291.0
# 1985   5130.0
# 1986   5814.0
# 1987   5775.0
# 1988   6960.0
# 1989   5539.0
# 1990   6128.0
# 1991   7591.0
# 1992   9915.0
# 1994   7569.0
# 1995  14292.0
# 1996  10795.0
# 1997   9072.0
# 1998   8183.0
# 1999   5341.0
# 2000   5869.0
# 2001  22774.0
# 2002   7162.0
# 2003   7384.0
# 2004  12022.0
# 2005  12784.0
# 2006  15550.0
# 2007  22524.0
# 2008  18998.0
# 2009  19138.0
# 2010  15947.0
# 2011  14659.0
# 2012  25445.0
# 2013  37688.0
# 2014  41128.0
# 2015  44043.0
# 2016  40001.0
# 2017  24927.0

# %%
year_wounded.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("Total people wounded in every year",fontsize=13)
plt.xlabel("Year",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("People Wounded",fontsize=13)
plt.show()

# %% [raw]
# 3) Year wise total casualties

# %%
year_casualties = df[["Year", "Casualty"]].groupby("Year").sum().sort_values(by = 'Year')
year_casualties
# Out:
#       Casualty
# Year
# 1970     386.0
# 1971     255.0
# 1972     975.0
# 1973     865.0
# 1974    1404.0
# 1975    1234.0
# 1976    1430.0
# 1977     974.0
# 1978    3059.0
# 1979    4606.0
# 1980    8045.0
# 1981    8188.0
# 1982    8478.0
# 1983   13491.0
# 1984   15741.0
# 1985   12224.0
# 1986   10790.0
# 1987   12257.0
# 1988   14168.0
# 1989   13691.0
# 1990   13276.0
# 1991   16020.0
# 1992   19657.0
# 1994   15259.0
# 1995   20395.0
# 1996   17761.0
# 1997   19996.0
# 1998   12871.0
# 1999    8734.0
# 2000   10272.0
# 2001   30503.0
# 2002   11967.0
# 2003   10701.0
# 2004   17765.0
# 2005   19115.0
# 2006   24930.0
# 2007   35348.0
# 2008   28155.0
# 2009   28411.0
# 2010   23774.0
# 2011   22905.0
# 2012   40942.0
# 2013   59961.0
# 2014   85618.0
# 2015   82896.0
# 2016   74872.0
# 2017   51372.0

# %%
year_casualties.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("Total casualties in every year",fontsize=13)
plt.xlabel("Year",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Casualties",fontsize=13)
plt.show()

# %% [markdown]
# ## Month wise Attack

# %% [raw]
# 1) Month wise total killed

# %%
month_killed = df[["Month", "Killed"]].groupby("Month").sum().sort_values(by = 'Month')
month_killed
# Out:
#         Killed
# Month
# 0          3.0
# 1      31320.0
# 2      30565.0
# 3      31479.0
# 4      34672.0
# 5      37310.0
# 6      38047.0
# 7      38558.0
# 8      38225.0
# 9      34485.0
# 10     35174.0
# 11     31054.0
# 12     30976.0

# %% [raw]
# 2) Month wise total wounded

# %%
month_wounded = df[["Month", "Wounded"]].groupby("Month").sum().sort_values(by = 'Month')
month_wounded
# Out:
#        Wounded
# Month
# 0          0.0
# 1      35097.0
# 2      37030.0
# 3      49929.0
# 4      40675.0
# 5      45224.0
# 6      41370.0
# 7      47151.0
# 8      50687.0
# 9      58054.0
# 10     41599.0
# 11     39512.0
# 12     37541.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
month_killed[:10].plot(kind="bar",color="lightgreen",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Month")
ax0.set_xlabel("Month")
ax0.set_ylabel("Number of People Killed")

#Wounded
month_wounded[:10].plot(kind="bar",color="lightgreen",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Month")
ax1.set_xlabel("Month")
ax1.set_ylabel("Number of People Wounded")
# Out:
# Text(0, 0.5, 'Number of People Wounded')

# %% [raw]
# 3) Month wise total casualties

# %%
month_casualties = df[["Month", "Casualty"]].groupby("Month").sum().sort_values(by = 'Month')
month_casualties
# Out:
#        Casualty
# Month
# 0           3.0
# 1       66417.0
# 2       67595.0
# 3       81408.0
# 4       75347.0
# 5       82534.0
# 6       79417.0
# 7       85709.0
# 8       88912.0
# 9       92539.0
# 10      76773.0
# 11      70566.0
# 12      68517.0

# %%
month_casualties.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("Total casualty in every month",fontsize=13)
plt.xlabel("Month",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Total Casualty",fontsize=13)
plt.show()

# %% [markdown]
# ## Regions wise Attack

# %% [raw]
# 1) Regions wise total killed

# %%
region_killed = df[["Region", "Killed"]].groupby("Region").sum().sort_values(by = 'Killed', ascending = False)
region_killed
# Out:
#                                Killed
# Region
# Middle East & North Africa   137642.0
# South Asia                   101319.0
# Sub-Saharan Africa            78386.0
# South America                 28849.0
# Central America & Caribbean   28708.0
# Southeast Asia                15637.0
# Eastern Europe                 7415.0
# Western Europe                 6694.0
# North America                  4916.0
# East Asia                      1152.0
# Central Asia                   1000.0
# Australasia & Oceania           150.0

# %%
region_wounded = df[["Region", "Wounded"]].groupby("Region").sum().sort_values(by = 'Wounded', ascending = False)
region_wounded
# Out:
#                               Wounded
# Region
# Middle East & North Africa   214308.0
# South Asia                   141360.0
# Sub-Saharan Africa            52857.0
# Southeast Asia                26259.0
# North America                 21531.0
# Western Europe                18332.0
# South America                 16704.0
# Eastern Europe                12045.0
# East Asia                      9213.0
# Central America & Caribbean    8991.0
# Central Asia                   2009.0
# Australasia & Oceania           260.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
region_killed[:10].plot(kind="bar",color="lightgreen",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Region")
ax0.set_xlabel("Region")
ax0.set_ylabel("Number of People Killed")

#Wounded
region_wounded[:10].plot(kind="bar",color="lightgreen",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Region")
ax1.set_xlabel("Region")
ax1.set_ylabel("Number of People Wounded")
# Out:
# Text(0, 0.5, 'Number of People Wounded')

# %%
month_casualties = df[["Region", "Casualty"]].groupby("Region").sum().sort_values(by = 'Casualty', ascending=False)
month_casualties
# Out:
#                              Casualty
# Region
# Middle East & North Africa   351950.0
# South Asia                   242679.0
# Sub-Saharan Africa           131243.0
# South America                 45553.0
# Southeast Asia                41896.0
# Central America & Caribbean   37699.0
# North America                 26447.0
# Western Europe                25026.0
# Eastern Europe                19460.0
# East Asia                     10365.0
# Central Asia                   3009.0
# Australasia & Oceania           410.0

# %%
month_casualties.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("Total casualty in every region",fontsize=13)
plt.xlabel("Region",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Total Casualty",fontsize=13)
plt.show()

# %% [markdown]
# #### Region wise attack in every year

# %%
reg = pd.crosstab(df.Year, df.Region)
reg.plot(kind="area", stacked=False,figsize=(20,10))
plt.title("Region wise attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %% [markdown]
# ## City Wise Attack

# %%
city = df['City'].value_counts().head(10)
city
# Out:
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Name: City, dtype: int64

# %%
# As the first city name is uknown we will take the next 10 city names
city[1:11]
# Out:
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Name: City, dtype: int64

# %%
city.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("City wise Attacks",fontsize=13)
plt.xlabel("Cities",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [raw]
# 1) People killed in top 10 cities

# %%
city_killed = df[["City", "Killed"]].groupby("City").sum().sort_values(by = "Killed", ascending = False).drop("Unknown")
city_killed.head(10)
# Out:
#                 Killed
# City
# Baghdad        21151.0
# Mosul           7140.0
# Mogadishu       3913.0
# Karachi         3688.0
# New York City   2838.0
# Tikrit          2679.0
# Kabul           2493.0
# Ramadi          2313.0
# Maiduguri       2235.0
# Aleppo          2125.0

# %% [raw]
# 2) People wounded in top 10 cities

# %%
city_wounded = df[["City", "Wounded"]].groupby("City").sum().sort_values(by = "Wounded", ascending = False).drop("Unknown")
city_wounded.head(10)
# Out:
#                Wounded
# City
# Baghdad        56725.0
# New York City  16781.0
# Kabul           5973.0
# Mosul           5787.0
# Karachi         5688.0
# Tokyo           5542.0
# Beirut          5341.0
# Nairobi         5024.0
# Kirkuk          5008.0
# Mogadishu       4955.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
city_killed[:10].plot(kind="bar",color="lightgreen",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each City")
ax0.set_xlabel("Cities")
ax0.set_ylabel("Number of People Killed")

#Wounded
city_wounded[:10].plot(kind="bar",color="lightgreen",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each City")
ax1.set_xlabel("Cities")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [raw]
# 3) Total casualties in top 10 cities

# %%
city_cas = df[["City", "Casualty"]].groupby("City").sum().sort_values(by = "Casualty", ascending = False).drop("Unknown")
city_cas.head(10)
# Out:
#                Casualty
# City
# Baghdad         77876.0
# New York City   19619.0
# Mosul           12927.0
# Karachi          9376.0
# Mogadishu        8868.0
# Kabul            8466.0
# Beirut           7257.0
# Kirkuk           6636.0
# Colombo          5906.0
# Aleppo           5748.0

# %%
city_cas[:10].plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("City wise Casualties",fontsize=13)
plt.xlabel("Cities",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# ## Terrorist Group wise attack

# %%
group = df['Group_Name'].value_counts().head(10).drop("Unknown")
group[:10]
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Name: Group_Name, dtype: int64

# %%
group.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("Group wise Attacks",fontsize=13)
plt.xlabel("Terrorist Groups",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [raw]
# 1) Total people killed by top 10 groups

# %%
grp_killed = df[["Group_Name", "Killed"]].groupby("Group_Name").sum().sort_values(by='Killed', ascending=False).drop("Unknown")
grp_killed.head(10)
# Out:
#                                                    Killed
# Group_Name
# Islamic State of Iraq and the Levant (ISIL)       38923.0
# Taliban                                           29410.0
# Boko Haram                                        20328.0
# Shining Path (SL)                                 11601.0
# Liberation Tigers of Tamil Eelam (LTTE)           10989.0
# Al-Shabaab                                         9330.0
# Farabundo Marti National Liberation Front (FMLN)   8065.0
# Nicaraguan Democratic Force (FDN)                  6662.0
# Tehrik-i-Taliban Pakistan (TTP)                    6042.0
# Revolutionary Armed Forces of Colombia (FARC)      5661.0

# %% [raw]
# 2) Total people got wounded by top 10 groups

# %%
grp_wounded = df[["Group_Name", "Wounded"]].groupby("Group_Name").sum().sort_values(by='Wounded', ascending=False).drop("Unknown")
grp_wounded.head(10)
# Out:
#                                              Wounded
# Group_Name
# Islamic State of Iraq and the Levant (ISIL)  30672.0
# Taliban                                      27932.0
# Al-Qaida                                     24512.0
# Liberation Tigers of Tamil Eelam (LTTE)      11031.0
# Al-Qaida in Iraq                             10343.0
# Tehrik-i-Taliban Pakistan (TTP)               9532.0
# Boko Haram                                    9473.0
# Al-Shabaab                                    7624.0
# Aum Shinri Kyo                                6003.0
# Kurdistan Workers' Party (PKK)                4908.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
grp_killed[:10].plot(kind="bar",color="lightgreen",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed by top 10 groups")
ax0.set_xlabel("Cities")
ax0.set_ylabel("Number of People Killed")

#Wounded
grp_wounded[:10].plot(kind="bar",color="lightgreen",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded by tpp 10 Groups")
ax1.set_xlabel("Cities")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [raw]
# 3) Total casualties by top 10 group

# %%
grp_cas = df[["Group_Name", "Casualty"]].groupby("Group_Name").sum().sort_values(by = "Casualty", ascending = False).drop("Unknown")
grp_cas.head(10)
# Out:
#                                                   Casualty
# Group_Name
# Islamic State of Iraq and the Levant (ISIL)        69595.0
# Taliban                                            57342.0
# Boko Haram                                         29801.0
# Al-Qaida                                           28372.0
# Liberation Tigers of Tamil Eelam (LTTE)            22020.0
# Al-Shabaab                                         16954.0
# Tehrik-i-Taliban Pakistan (TTP)                    15574.0
# Al-Qaida in Iraq                                   14724.0
# Shining Path (SL)                                  14632.0
# Farabundo Marti National Liberation Front (FMLN)   12130.0

# %%
grp_cas.head(10).plot(kind="bar",color="lightgreen",figsize=(15,6))
grp_cas[:10].plot(kind="bar",color="lightgreen",figsize=(15,6),ax=ax1)
ax1.set_title("Total casualties by tpp 10 Groups")
ax1.set_xlabel("Cities")
ax1.set_ylabel("Casualties")

plt.show()

# %% [markdown]
# ## Killed by Attack type

# %%
ak = df['Attack_Type'].value_counts().head(10).drop("Unknown")
ak[:10]
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attack_Type, dtype: int64

# %%
ak.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("Attack type wise Attacks",fontsize=13)
plt.xlabel("Attack Type",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [raw]
# 1) Total People killed by eack attack type

# %%
ak_killed = df[["Attack_Type", "Killed"]].groupby("Attack_Type").sum().sort_values(by='Killed', ascending=False).drop("Unknown")
ak_killed.head(10)
# Out:
#                                        Killed
# Attack_Type
# Armed Assault                        160297.0
# Bombing/Explosion                    157321.0
# Assassination                         24920.0
# Hostage Taking (Kidnapping)           24231.0
# Hostage Taking (Barricade Incident)    4478.0
# Hijacking                              3718.0
# Facility/Infrastructure Attack         3642.0
# Unarmed Assault                         880.0

# %% [raw]
# 2) Total people wounded by each attack Type

# %%
ak_wounded = df[["Attack_Type", "Wounded"]].groupby("Attack_Type").sum().sort_values(by='Wounded', ascending=False).drop("Unknown")
ak_wounded.head(10)
# Out:
#                                       Wounded
# Attack_Type
# Bombing/Explosion                    372686.0
# Armed Assault                         77366.0
# Hijacking                             17001.0
# Unarmed Assault                       14027.0
# Assassination                         13887.0
# Hostage Taking (Kidnapping)            6446.0
# Hostage Taking (Barricade Incident)    3966.0
# Facility/Infrastructure Attack         3765.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
ak_killed.plot(kind="bar",color="lightgreen",figsize=(17,6),ax=ax0)
ax0.set_title("People Killed in each Attack Type")
ax0.set_xlabel("Attack Types")
ax0.set_ylabel("Number of people Killed")

#Wounded
ak_wounded.plot(kind="bar",color="lightgreen",figsize=(17,6),ax=ax1)
ax1.set_title("People Wounded in each Attack Type")
ax1.set_xlabel("Attack Types")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [raw]
# 3) Total casualties by each attack type

# %%
ak_cas = df[["Attack_Type", "Casualty"]].groupby("Attack_Type").sum().sort_values(by='Casualty', ascending=False).drop("Unknown")
ak_cas.head(10)
# Out:
#                                      Casualty
# Attack_Type
# Bombing/Explosion                    530007.0
# Armed Assault                        237663.0
# Assassination                         38807.0
# Hostage Taking (Kidnapping)           30677.0
# Hijacking                             20719.0
# Unarmed Assault                       14907.0
# Hostage Taking (Barricade Incident)    8444.0
# Facility/Infrastructure Attack         7407.0

# %%
ak_cas.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("Total casualties wise Attacks",fontsize=13)
plt.xlabel("Attack Type",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Casualties",fontsize=13)
plt.show()

# %% [markdown]
# ##  Attack by Target type

# %%
at = df['Target_Type'].value_counts().head(10).drop("Unknown")
at[:10]
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Name: Target_Type, dtype: int64

# %%
at.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("Target type wise Attacks",fontsize=13)
plt.xlabel("Target Type",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [raw]
# 1) Total People killed by eack attack type

# %%
at_killed = df[["Target_Type", "Killed"]].groupby("Target_Type").sum().sort_values(by='Killed', ascending=False).drop("Unknown")
at_killed.head(10)
# Out:
#                                   Killed
# Target_Type
# Private Citizens & Property     140504.0
# Military                        106047.0
# Police                           53704.0
# Government (General)             26071.0
# Business                         23487.0
# Transportation                   13916.0
# Religious Figures/Institutions   13413.0
# Terrorists/Non-State Militia      9088.0
# Airports & Aircraft               3767.0
# Educational Institution           3745.0

# %% [raw]
# 2) Total people wounded by each attack Type

# %%
at_wounded = df[["Target_Type", "Wounded"]].groupby("Target_Type").sum().sort_values(by='Wounded', ascending=False).drop("Unknown")
at_wounded.head(10)
# Out:
#                                  Wounded
# Target_Type
# Private Citizens & Property     178672.0
# Military                         71038.0
# Police                           64703.0
# Business                         54531.0
# Government (General)             41184.0
# Transportation                   40679.0
# Religious Figures/Institutions   24477.0
# Government (Diplomatic)          10359.0
# Educational Institution          10227.0
# Terrorists/Non-State Militia      8223.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
at_killed.plot(kind="bar",color="lightgreen",figsize=(17,6),ax=ax0)
ax0.set_title("People Killed in each Target Type")
ax0.set_xlabel("Target Types")
ax0.set_ylabel("Number of people Killed")

#Wounded
at_wounded.plot(kind="bar",color="lightgreen",figsize=(17,6),ax=ax1)
ax1.set_title("People Wounded in each Target Type")
ax1.set_xlabel("Target Types")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [raw]
# 3) Total casualties by each attack type

# %%
at_cas = df[["Target_Type", "Casualty"]].groupby("Target_Type").sum().sort_values(by='Casualty', ascending=False).drop("Unknown")
at_cas.head(10)
# Out:
#                                 Casualty
# Target_Type
# Private Citizens & Property     319176.0
# Military                        177085.0
# Police                          118407.0
# Business                         78018.0
# Government (General)             67255.0
# Transportation                   54595.0
# Religious Figures/Institutions   37890.0
# Terrorists/Non-State Militia     17311.0
# Educational Institution          13972.0
# Government (Diplomatic)          13398.0

# %%
at_cas.plot(kind="bar",color="lightgreen",figsize=(15,6))
plt.title("Total casualties wise Target",fontsize=13)
plt.xlabel("Attack Type",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Casualties",fontsize=13)
plt.show()

# %% [raw]
# -- From the above analysis we conclude that
# 1. Iraq country has highest number of attacks (24636)
# 2. Middle and East Africa region has highest number of attacks (50474)
# 3. Explosives are the most weapon used by terrorsits (92426).
# 4. From the analysis we can see that on 2014 the number of terrorist activities were the highest in Iraq Country (16806)
# 5. Private citizens and Property were the main targets in terrorism activity (43510)
# 6. Bombing and Explosion methods were most commonly used in terrorism activity (82255).
# 7. Taliban is most Notorious group with highest number of terrorist activitiies (7478)
